# %%
import class_stats as cs

# %%
# Show stats expectation by limits
cs.starSteel.player_limits()
# Out:
#   Stats  door 8 (lvl 45)  door 9 (lvl 50)  door 10 (lvl 60)  door 11 (lvl 70)  \
# 0   STR               24               27                32                37
# 1   CON               74               82                98               114
# 2   INT                0                0                 0                 0
# 3   WIS                8                9                11                12
# 4   SPD               32               35                42                49
#
#    door 12 (lvl 80)  door 13 (lvl 100)  door 14 (lvl 120)  door 15 (lvl 150)  \
# 0                43                 53                 64                 80
# 1               130                162                194                242
# 2                 0                  0                  0                  0
# 3                14                 18                 21                 27
# 4                56                 70                 84                105
#
# ...

# %%
# Check player objectives
cs.lapis.check_stat_level_max()
cs.lapis.show_final_stats_with_PP()
# Out:
# There are still 32 points to attribute.
# Final stats with PP:
#
# STR: 48
# CON: 348
# INT: 536
# WIS: 100
# SPD: 48

# %%
cs.celto.create_team(cs.celto, cs.pulsaar, cs.loctra, cs.harmisteas)
# Out:
#    STR  CON  INT  WIS  SPD       Names
# 0    0  288  532   52    0       celto
# 1  318  318    0  102  102     Pulsaar
# 2    0  452  284  102    0      loctra
# 3    0  352  352  102   52  Harmisteas
